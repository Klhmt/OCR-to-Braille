# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
from separation_en_caractères import separe_en_caracteres
from separation_en_lignes import separe_en_lignes

# %%
image = cv2.imread('Images/scan.bmp')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
(thresh, image_binary) = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)

indices_lignes = separe_en_lignes(image_binary)

# %%
plt.figure(figsize=(40,20))
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
for elt in indices_lignes : 
    plt.figure(figsize=(40,20))
    plt.imshow(image[elt[0]:elt[1]])
    plt.axis('off')
    plt.show()

# %%
import os

ligne_0 = indices_lignes[0]

image_ligne_0 = image[ligne_0[0]:ligne_0[1]]
image_ligne_0_binaire = image_binary[ligne_0[0]:ligne_0[1], 650:1200]

plt.figure(figsize=(40,20))
plt.imshow(image_ligne_0_binaire, cmap='gray')
plt.axis('off')
plt.show()
"""
output_dir = 'Images'
output_filename = 'ligne_0.bmp' 
output_filename_binaire = 'ligne_0_binaire.bmp'

cropped_image_path = os.path.join(output_dir, output_filename)
cropped_image_path_binaire = os.path.join(output_dir, output_filename_binaire)

cv2.imwrite(cropped_image_path,image_ligne_0)
cv2.imwrite(cropped_image_path_binaire,image_ligne_0_binaire)
"""
# Out:
# "\noutput_dir = 'Images'\noutput_filename = 'ligne_0.bmp' \noutput_filename_binaire = 'ligne_0_binaire.bmp'\n\ncropped_image_path = os.path.join(output_dir, output_filename)\ncropped_image_path_binaire = os.path.join(output_dir, output_filename_binaire)\n\ncv2.imwrite(cropped_image_path,image_ligne_0)\ncv2.imwrite(cropped_image_path_binaire,image_ligne_0_binaire)\n"

# %%
print(ligne_0[1]-ligne_0[0])
print(len(image[0]))
print((ligne_0[1]-ligne_0[0])*len(image[0]))
# Out:
# 93
# 4819
# 448167
